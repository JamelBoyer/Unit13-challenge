# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

# %%
# Alternatively, use the provided csv file:
file_path = Path(".\Resources\crypto_data.csv")

# Create a DataFrame

crypto_data_df = pd.read_csv(Path(".\Resources\crypto_data.csv"))


crypto_data_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
import pandas as pd

crypto_df = crypto_data_df[["CoinName", "Algorithm", "IsTrading", "ProofType", "TotalCoinsMined", "TotalCoinSupply"]]

crypto_df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0            42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1            365Coin       X11       True   PoW/PoS              NaN
# 2            404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3          SixEleven   SHA-256       True       PoW              NaN
# 4                808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# 1247     BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# 1248      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# 1249     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# 1250  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# 1251       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
# Keep only cryptocurrencies that are trading


crypto_df= crypto_df[crypto_df['IsTrading'] == True]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df["Algorithm"] != "N/A"]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(["IsTrading"],axis = 1)

crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 1         365Coin          X11   PoW/PoS              NaN      2300000000
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 3       SixEleven      SHA-256       PoW              NaN          611000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# 1243   Super Zero       Ethash       PoW              NaN      1000000000
# 1244          UOS      SHA-256      DPoI              NaN      1000000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna()
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df["TotalCoinsMined"]> 0]

crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df.dropna()
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df

CoinName_df = crypto_df.filter(['CoinName'], axis=1)
CoinName_df
# Out:
#          CoinName
# 0         42 Coin
# 2         404Coin
# 5       EliteCoin
# 7         Bitcoin
# 8        Ethereum
# ...           ...
# 1238       ZEPHYR
# 1242      Gapcoin
# 1245       Beldex
# 1246      Horizen
# 1247  BitcoinPlus
#
# [532 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm

crypto_df = crypto_df[["Algorithm", "ProofType", "TotalCoinsMined","TotalCoinSupply"]]

crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
# Create dummy variables for text features

#The data is not the same length so I'll run dummies then merge. 
crypto = pd.get_dummies(crypto_df['Algorithm'])
dummy = pd.get_dummies(crypto_df['ProofType'])
combined = pd.concat([crypto,dummy],axis =1)
df = crypto_df.merge(combined,left_index = True,right_index = True)
crypto_dummy_df = df.drop(['Algorithm','ProofType'],axis = 1)
crypto_dummy_df
# Out:
#       TotalCoinsMined TotalCoinSupply  1GB AES Pattern Search  536  Argon2d  \
# 0        4.199995e+01              42                       0    0        0
# 2        1.055185e+09       532000000                       0    0        0
# 5        2.927942e+10    314159265359                       0    0        0
# 7        1.792718e+07        21000000                       0    0        0
# 8        1.076842e+08               0                       0    0        0
# ...               ...             ...                     ...  ...      ...
# 1238     2.000000e+09      2000000000                       0    0        0
# 1242     1.493105e+07       250000000                       0    0        0
# 1245     9.802226e+08      1400222610                       0    0        0
# 1246     7.296538e+06        21000000                       0    0        0
# 1247     1.283270e+05         1000000                       0    0        0
#
# ...

# %%
# Standardize data
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
 




 
# standardization of dependent variables
df_scaled = StandardScaler().fit_transform(crypto_dummy_df)
df_scaled
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans

pca = PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
pca_data = pca.fit_transform(df_scaled)

pca_data[:5]
pca.explained_variance_ratio_
# Out:
# array([0.02793044, 0.02139826, 0.02049428])

# %%
pca_data_df = pd.DataFrame(
    data=pca_data, columns=["pca 1", "pca 2", "pca 3"],
    index= CoinName_df.index
)
pca_data_df.head()
# Out:
#       pca 1     pca 2     pca 3
# 0 -0.337718  1.048708 -0.536568
# 2 -0.321045  1.048817 -0.536926
# 5  2.318168  1.650667 -0.568231
# 7 -0.143134 -1.333833  0.147652
# 8 -0.155872 -1.996319  0.374939

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values


for i in k:
    k_model = KMeans(n_clusters=i, random_state=1)
    k_model.fit(pca_data_df)
    inertia.append(k_model.inertia_)
# Create the Elbow Curve using hvPlot

elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()

df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# c:\Users\Jamel\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   f"KMeans is known to have a memory leak on Windows "
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=3, random_state=0)
# Fit the model
model.fit(pca_data_df)
# Predict clusters
Cluster_Predic_3 = model.predict(pca_data_df)
# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([CoinName_df, crypto_df, pca_data_df],axis =1)
clustered_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
#          pca 1     pca 2     pca 3
# 0    -0.337718  1.048708 -0.536568
# ...

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
import hvplot
import hvplot.pandas

clustered_df["TotalCoinSupply"]= clustered_df["TotalCoinSupply"].astype(float)/100000000
clustered_df["TotalCoinsMined"]= clustered_df["TotalCoinsMined"].astype(float)/100000000

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
clustered_df.hvplot(
    kind="scatter",
    x= "TotalCoinsMined",
    y= "TotalCoinSupply",
    hover_cols=["CoinName"],
     by= "Algorithm")
# Out:
# :NdOverlay   [Algorithm]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply,CoinName)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
tradable_df = clustered_df.filter(items = ['CoinName','Algorithm','ProofType','TotalCoinsMined','TotalCoinSupply'],axis=1)
tradable_df.hvplot.table()
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinsMined,TotalCoinSupply]

# %%
# Print the total number of tradable cryptocurrencies
print(f"The total number of tradable cryptocurrencies is {CoinName_df.count()}")
# Out:
# The total number of tradable cryptocurrencies is CoinName    532
# dtype: int64
